# %% [markdown]
# #### Muhammad Aryasatya N | 22083010085 | Data Mining (B) | Tugas Sub-CPMK 3

# %% [markdown]
# ### Import Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %% [markdown]
# ### Load Dataset

# %%
data = pd.read_csv("Data Outlier Testing.csv")
data
# Out:
#         Var 1     Var 2     Var 3     Var 4     Var 5     Var 6     Var 7  \
# 0    0.435518  0.038492  0.551343  0.140049  0.899545  0.588684  0.299706
# 1    0.633197  0.034490  0.319406  0.879141  0.163079  0.184356  0.160583
# 2    0.421558  0.299824  0.602220  0.521654  0.954621  0.547448  0.882898
# 3    0.817491  0.647528  0.046214  0.487270  0.053872  0.817499  0.390589
# 4    0.291513  0.474018  0.065267  0.410573  0.903696  0.466520  0.196878
# ..        ...       ...       ...       ...       ...       ...       ...
# 995  0.088368  0.402631  0.726744  0.053558  0.920036  0.599621  0.132750
# 996  0.709031  0.869773  0.563853  0.667340  0.144001  0.116051  0.352950
# 997  0.281746  0.523779  0.290838  0.837198  0.079527  0.166336  0.468142
# 998  0.159682  0.825127  0.716445  0.069445  0.032148  0.654702  0.028203
# 999  0.297497  0.464243  0.577540  0.153434  0.761632  0.549225  0.788681
#
#         Var 8     Var 9    Var 10
# 0    0.245713  0.367375  0.452970
# 1    0.104973  0.294980  0.429709
# 2    0.586641  0.840204  0.212529
# 3    0.394750  0.736854  0.442689
# 4    0.165370  0.297764  0.467911
# ..        ...       ...       ...
# 995  0.119502  0.251470  0.482979
# 996  0.372501  0.343832  0.648546
# 997  0.545292  0.352506  0.686788
# 998  0.886761  0.165482  0.116204
# 999  0.755917  0.611247  0.555821
#
# [1000 rows x 10 columns]

# %% [markdown]
# ### Menampilkan Persebaran Data Sebelum Penanganan Outlier

# %%
# Menampilkan persebaran data sebelum penanganan outlier
print('\nPersebaran data sebelum ditangani Outlier: ')
data.describe()
# Out:
# Persebaran data sebelum ditangani Outlier:
#              Var 1        Var 2        Var 3        Var 4        Var 5  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean      0.491362     0.490200     0.509077     0.497362     0.586120
# std       0.259138     0.251931     0.256606     0.263562     0.334658
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.287458     0.291449     0.337802     0.256147     0.169680
# 50%       0.492070     0.488656     0.510077     0.497537     0.782019
# 75%       0.694192     0.686531     0.686914     0.731949     0.847956
# max       0.994431     1.000000     1.000000     1.000000     1.000000
#
#              Var 6        Var 7        Var 8        Var 9       Var 10
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean      0.514636     0.508270     0.457541     0.477685     0.495760
# std       0.317470     0.278483     0.220129     0.241432     0.211677
# min       0.000000     0.000000     0.000000     0.000000     0.014495
# 25%       0.142587     0.246021     0.245539     0.291452     0.329904
# 50%       0.537953     0.465679     0.515619     0.387753     0.488891
# 75%       0.856512     0.804935     0.626757     0.723674     0.659528
# max       1.000000     1.000000     1.000000     0.988732     1.000000

# %% [markdown]
# ### Visualisasi Outlier

# %%
# Ukuran plot
plt.figure(figsize=(20, 15))

# Loop melalui setiap kolom dari Var 1 hingga Var 10
for i in range(1, 11):
    # Memilih kolom yang akan divisualisasikan
    data_col = data[f'Var {i}']

    # Membuat subplot untuk setiap kolom
    plt.subplot(4, 5, i)

    # Box Plot
    sns.boxplot(data=data_col, color='#7E352D')
    plt.title(f'Var {i} - Box Plot')

plt.tight_layout()
plt.show()

# %%
# Ukuran plot
plt.figure(figsize=(20, 15))

# Loop melalui setiap kolom dari Var 1 hingga Var 10
for i in range(1, 11):
    # Memilih kolom yang akan divisualisasikan
    data_col = data[f'Var {i}']

    # Membuat subplot untuk setiap kolom
    plt.subplot(4, 5, i)

    # Scatter Plot
    plt.scatter(np.arange(len(data_col)), data_col, color='#7E352D')
    plt.title(f'Var {i} - Scatter Plot')

plt.tight_layout()
plt.show()

# %%
# Ukuran plot
plt.figure(figsize=(20, 15))

# Loop melalui setiap kolom dari Var 1 hingga Var 10
for i in range(1, 11):
    # Memilih kolom yang akan divisualisasikan
    data_col = data[f'Var {i}']

    # Membuat subplot untuk setiap kolom
    plt.subplot(4, 5, i)

    # Histogram
    sns.histplot(data_col, color='#7E352D', kde=True)
    plt.title(f'Var {i} - Histogram')

plt.tight_layout()
plt.show()

# %%
# Ukuran plot
plt.figure(figsize=(20, 15))

# Loop melalui setiap kolom dari Var 1 hingga Var 10
for i in range(1, 11):
    # Memilih kolom yang akan divisualisasikan
    data_col = data[f'Var {i}']

    # Membuat subplot untuk setiap kolom
    plt.subplot(4, 5, i)

    # QQ Plot
    stats.probplot(data_col, dist="norm", plot=plt)
    plt.title(f'Var {i} - QQ Plot')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Visualisasi Outlier Dalam Satu Output

# %%
# Ukuran plot
plt.figure(figsize=(15, 10))

# Loop melalui setiap kolom dari Var 1 hingga Var 10
for i in range(1, 11):
    # Memilih kolom yang akan divisualisasikan
    data_col = data[f'Var {i}']
    
    # subplot untuk setiap kolom
    plt.subplot(4, 10, i)
    
    # Box Plot
    sns.boxplot(data=data_col)
    plt.title(f'Var {i} - Box Plot')

    # subplot untuk scatter plot
    plt.subplot(4, 10, i + 10)
    plt.scatter(np.arange(len(data_col)), data_col)
    plt.title(f'Var {i} - Scatter Plot')

    # subplot untuk histogram
    plt.subplot(4, 10, i + 20)
    sns.histplot(data_col, kde=True)
    plt.title(f'Var {i} - Histogram')

    # subplot untuk QQ plot
    plt.subplot(4, 10, i + 30)
    stats.probplot(data_col, dist="norm", plot=plt)
    plt.title(f'Var {i} - QQ Plot')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Deteksi Outlier Secara Teoritis

# %% [markdown]
# IQR

# %%
# Menghitung kuartil pertama (Q1) dan kuartil ketiga (Q3)
Q1 = data.quantile(0.25)
Q3 = data.quantile(0.75)

# Menghitung IQR
IQR = Q3 - Q1

# Menghitung batas atas (upper fence) dan batas bawah (lower fence) untuk outlier
maximum = Q3 + (1.5 * IQR)
minimum = Q1 - (1.5 * IQR)

# Mengidentifikasi outlier
more_than = (data > maximum)
lower_than = (data < minimum)

# Menggantikan nilai outlier dengan nilai maksimum atau minimum yang telah ditentukan
data_no_outliers = data.mask(more_than, maximum, axis=1)
data_no_outliers = data_no_outliers.mask(lower_than, minimum, axis=1)

# Menampilkan persebaran data setelah ditangani outlier
if data.equals(data_no_outliers):
    print("Tidak ada outlier yang terdeteksi dalam dataset.")
else:
    print('\nPersebaran data setelah ditangani Outlier: ')
    print(data_no_outliers.describe())
# Out:
# Tidak ada outlier yang terdeteksi dalam dataset.

# %% [markdown]
# Z-Score

# %%
def detect_outliers_zscore(data, threshold=3):
    z_scores = (data - data.mean()) / data.std()
    return np.abs(z_scores) > threshold

# Menggunakan threshold 3 (nilai default) untuk mendeteksi outlier
outliers_zscore = detect_outliers_zscore(data)

# Menampilkan indeks baris yang mengandung outlier
outlier_indices = np.where(outliers_zscore.any(axis=1))[0]
print("Indeks baris yang mengandung outlier:")
print(outlier_indices)
# Out:
# Indeks baris yang mengandung outlier:
# []
